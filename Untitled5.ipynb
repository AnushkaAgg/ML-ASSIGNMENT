# %% [markdown]
# # ML ASSIGNMENT
#
# NAME : ANUSHKA AGARWAL
# SECTION: ML
# CLASS ROLL NO.: 11

# %% [markdown]
# WITHOUT USING FUNCTIONS

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import math
def dist(d1,d2):
    x=pow((d1[0]-d2[0]),2)
    y=pow((d1[1]-d2[1]),2)
    distance=(math.sqrt(x+y))
    return distance    
def minimum(A):
    p=[0,0]
    mn=1000
    for i in range(0,200):
        for j in range(0,i):
            if(A[i][j]>0 and A[i][j]<mn):
                mn=A[i][j]
                p[0]=i
                p[1]=j
    return p
def newpoint(pt):
    x=float(pt[0][0])+float(pt[1][0])
    x=x/2
    y=float(pt[0][1])+float(pt[1][1])
    y=y/2
    midpoint=[x,y]
    return midpoint

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import math
from sklearn.cluster import AgglomerativeClustering
##import scipy.cluster.hierarchy as sch
#from scipy.cluster.hierarchy import dendogram,linkage
import array as arr
url="C:\\Users\\user\\Downloads\customers.csv"
dataset=pd.read_csv(url)
X= dataset.iloc[: ,[3,4]].values
x1=X[0]
c=200
f=0
while(c!=1):
    c=c-1
    f=f+1
    mat=list()
    for i in range(0,len(X)):
        d=[]
        X1=X[i]
        for j in range(0,len(X)):
            d.append(0)
        for j in range(1,len(X)):
            X2=X[j]
            d[j]=dist(X1,X2)
            mat.append(d)
    d=minimum(mat)
    pts=list()
    p1=X[d[0]]
    pts.append(p1)
    np.delete(X,p1)
    p2=X[d[1]-1]
    pts.append(p2)
    np.delete(X,p2)
    midpoint=newpoint(pts)
    np.append(X,midpoint)
for i in range(0,len(X)) :
    K=X[i]
    plt.scatter(K[0],K[1])  
plt.show()

# %% [markdown]
# USING FUNCTIONS

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch
dataset = pd.read_csv('C:\\Users\\user\\Downloads\customers.csv')

X = dataset.iloc[:, [3, 4]].values
dendrogram = sch.dendrogram(sch.linkage(X, method='ward'))
model = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')
model.fit(X)
labels = model.labels_

# %%
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')
plt.scatter(X[labels==3, 0], X[labels==3, 1], s=50, marker='o', color='purple')
plt.scatter(X[labels==4, 0], X[labels==4, 1], s=50, marker='o', color='orange')
plt.show()
